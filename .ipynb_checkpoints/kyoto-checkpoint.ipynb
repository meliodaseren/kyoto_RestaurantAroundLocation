# %%
import pandas as pd
import bokeh

# %%
kyoto = pd.read_csv("site_restaurant_join.csv")

# %%
print(kyoto)
# Out:
#       r0001  s1  2.037775893  669  97.3339141         一蘭拉麵  35.0058787  \
# 0     r0001  s2     2.023311  358   90.341827         一蘭拉麵  35.0058787
# 1     r0001  s3     4.376297  517   93.500844         一蘭拉麵  35.0058787
# 2     r0001  s4    13.429932   58   63.944158         一蘭拉麵  35.0058787
# 3     r0001  s5     2.234828   43   78.766910         一蘭拉麵  35.0058787
# 4     r0001  s6     2.187607  104   79.383957         一蘭拉麵  35.0058787
# 5     r0001  s7     5.129946   43   72.081132         一蘭拉麵  35.0058787
# 6     r0001  s8     1.971776  132   58.970203         一蘭拉麵  35.0058787
# 7     r0001  s9     8.330669  373   89.341354         一蘭拉麵  35.0058787
# 8     r0002  s1     3.328348  555   87.125239   抹茶.甜點 中村藤吉  34.9853943
# 9     r0002  s2     1.256989  414   98.201541   抹茶.甜點 中村藤吉  34.9853943
# 10    r0002  s3     2.551602  498   94.373140   抹茶.甜點 中村藤吉  34.9853943
# 11    r0002  s4    11.577387   83   81.900563   抹茶.甜點 中村藤吉  34.9853943
# ...

# %%
print(kyoto.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2888 entries, 0 to 2887
# Data columns (total 11 columns):
# r0001          2888 non-null object
# s1             2888 non-null object
# 2.037775893    2888 non-null float64
# 669            2888 non-null int64
# 97.3339141     2888 non-null float64
# 一蘭拉麵           2888 non-null object
# 35.0058787     2888 non-null object
# 135.7681023    2888 non-null object
# 二條城            2888 non-null object
# 35.0142299     2888 non-null float64
# 135.748218     2888 non-null float64
# dtypes: float64(4), int64(1), object(6)
# memory usage: 248.3+ KB
# None

# %%
type(kyoto)
# Out:
# pandas.core.frame.DataFrame

# %%
kyoto.head()
# Out:
#    r0001  s1  2.037775893  669  97.3339141  一蘭拉麵  35.0058787  135.7681023  \
# 0  r0001  s2     2.023311  358   90.341827  一蘭拉麵  35.0058787  135.7681023
# 1  r0001  s3     4.376297  517   93.500844  一蘭拉麵  35.0058787  135.7681023
# 2  r0001  s4    13.429932   58   63.944158  一蘭拉麵  35.0058787  135.7681023
# 3  r0001  s5     2.234828   43   78.766910  一蘭拉麵  35.0058787  135.7681023
# 4  r0001  s6     2.187607  104   79.383957  一蘭拉麵  35.0058787  135.7681023
#
#       二條城  35.0142299  135.748218
# 0   三十三間堂   34.987884  135.771713
# 1    千本鳥居   34.966813  135.774749
# 2  平等院鳳凰堂   34.889291  135.807678
# 3    京都御所   35.025413  135.762125
# 4     京都塔   34.987477  135.759493
